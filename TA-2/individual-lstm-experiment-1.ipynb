# %% [markdown]
# # Individual LSTM Experiment Univariat Dengan Lookback 14

# %% [markdown]
# ### 1. Import Library dan Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import root_mean_squared_log_error
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import warnings
warnings.filterwarnings('ignore')

# Set seed untuk reproduktibilitas
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### 2. Load Dataset
# Memuat dataset `train.csv`.

# %%
# Load dataset
df_train = pd.read_csv('../datasets/train.csv', parse_dates=['date'])
df_train.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0
# 1   1 2013-01-01          1   BABY CARE    0.0            0
# 2   2 2013-01-01          1      BEAUTY    0.0            0
# 3   3 2013-01-01          1   BEVERAGES    0.0            0
# 4   4 2013-01-01          1       BOOKS    0.0            0

# %% [markdown]
# ### 3. Fungsi Pembantu (Data Preparation, Model Building, & Evaluasi)
# Fungsi-fungsi pembantu ini digunakan untuk mempersiapkan data sekuensial, membuat model LSTM (Sederhana & Kompleks), serta melakukan proses latih dan evaluasi untuk setiap kombinasi store dan family.
#
# > **Catatan Penting Pelatihan**: Model dilatih menggunakan `loss='mse'` (Mean Squared Error) pada data terskala `[0, 1]` untuk mencegah masalah *vanishing gradient* / *predictions stuck at 0* pada fungsi `msle`. Evaluasi akhir tetap diukur menggunakan metrik **RMSLE** (Root Mean Squared Logarithmic Error).

# %%
def create_dataset(dataset, look_back=30):
    X, Y = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

def prepare_data_lstm(df, store_nbr, family, look_back=30, train_ratio=0.8):
    df_filtered = df[(df['store_nbr'] == store_nbr) & (df['family'] == family)]
    df_filtered = df_filtered.groupby('date')['sales'].sum().reset_index().set_index('date').asfreq('D').fillna(0).reset_index()

    sales_data = df_filtered['sales'].values.reshape(-1, 1)

    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(sales_data)

    X, y = create_dataset(scaled_data, look_back)
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))

    train_size = int(len(X) * train_ratio)
    X_train, X_test = X[:train_size], X[train_size:]
    y_train, y_test = y[:train_size], y[train_size:]
    
    actual_sales = sales_data[look_back:]
    actual_y_test = actual_sales[train_size:]

    return {
        'df_filtered': df_filtered,
        'scaler': scaler,
        'X_train': X_train,
        'X_test': X_test,
        'y_train': y_train,
        'y_test': y_test,
        'actual_y_test': actual_y_test,
        'look_back': look_back
    }

def build_simple_lstm(look_back=30):
    tf.random.set_seed(42)
    model = Sequential()
    model.add(LSTM(64, activation='tanh', dropout=0.2, input_shape=(look_back, 1)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

def build_complex_lstm(look_back=30):
    tf.random.set_seed(42)
    model = Sequential()
    model.add(LSTM(64, activation='tanh', return_sequences=True, input_shape=(look_back, 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(32, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')
    return model

def train_and_evaluate(model, data_dict, model_name, store_nbr, family, epochs=50, batch_size=32):
    X_train = data_dict['X_train']
    y_train = data_dict['y_train']
    X_test = data_dict['X_test']
    y_test = data_dict['y_test']
    scaler = data_dict['scaler']
    actual_y_test = data_dict['actual_y_test']
    df_filtered = data_dict['df_filtered']

    print(f"=== Training {model_name} (Store {store_nbr} - {family}) ===")
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test, y_test),
        verbose=1
    )

    # Plot Learning Curve
    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'], label='Train Loss (MSE)')
    plt.plot(history.history['val_loss'], label='Validation Loss (MSE)')
    plt.title(f'Learning Curve {model_name} - Store {store_nbr} | {family}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Prediksi & Inverse Transform
    y_pred_scaled = model.predict(X_test)
    y_pred = scaler.inverse_transform(y_pred_scaled)
    y_pred = np.where(y_pred < 0, 0, y_pred)

    # RMSLE Evaluation
    rmsle = root_mean_squared_log_error(actual_y_test, y_pred)
    print(f"[{model_name}] RMSLE (Store {store_nbr} - {family}): {rmsle:.4f}\n")

    # Plot Actual vs Predicted
    plt.figure(figsize=(14, 5))
    plt.plot(df_filtered['date'].iloc[-len(actual_y_test):], actual_y_test, label='Actual Sales', color='blue')
    plt.plot(df_filtered['date'].iloc[-len(y_pred):], y_pred, label=f'Predicted Sales ({model_name})', color='red', alpha=0.8)
    plt.title(f'Actual vs Predicted Sales ({model_name}) - Store {store_nbr} | {family}')
    plt.xlabel('Date')
    plt.ylabel('Sales')
    plt.legend()
    plt.grid(True)
    plt.show()

    return rmsle

# %% [markdown]
# ---
# ## Kombinasi 1: Store 23 - EGGS

# %%
# Prepare Data Kombinasi 1 (Store 23, EGGS)
data_comb1 = prepare_data_lstm(df_train, store_nbr=23, family='EGGS', look_back=14)
print(f"Data Kombinasi 1 (Store 23 - EGGS) Siap!")
print(f"Shape X_train: {data_comb1['X_train'].shape}, Shape X_test: {data_comb1['X_test'].shape}")
# Out:
# Data Kombinasi 1 (Store 23 - EGGS) Siap!
# Shape X_train: (1339, 14, 1), Shape X_test: (335, 14, 1)

# %% [markdown]
# ### Kombinasi 1 - Model LSTM Sederhana

# %%
model_simple_comb1 = build_simple_lstm(look_back=14)
rmsle_simple_comb1 = train_and_evaluate(
    model_simple_comb1, data_comb1, 
    model_name="Simple LSTM", store_nbr=23, family="EGGS", 
    epochs=50, batch_size=32
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# === Training Simple LSTM (Store 23 - EGGS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 110ms/step - loss: 0.0492 - val_loss: 0.0100
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0159 - val_loss: 0.0105
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0124 - val_loss: 0.0105
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0123 - val_loss: 0.0102
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0123 - val_loss: 0.0103
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0123 - val_loss: 0.0101
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0123 - val_loss: 0.0102
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 41ms/step - loss: 0.0122 - val_loss: 0.0101
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0123 - val_loss: 0.0101
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0124 - val_loss: 0.0100
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - val_loss: 0.0101
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0121 - val_loss: 0.0101
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0121 - val_loss: 0.0099
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0120 - val_loss: 0.0099
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0120 - val_loss: 0.0100
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0120 - val_loss: 0.0098
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0119 - val_loss: 0.0097
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0115 - val_loss: 0.0100
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0116 - val_loss: 0.0106
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0116 - val_loss: 0.0105
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0115 - val_loss: 0.0106
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0115 - val_loss: 0.0106
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 0.0114 - val_loss: 0.0114
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0115 - val_loss: 0.0111
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0113 - val_loss: 0.0108
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0112 - val_loss: 0.0109
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0111 - val_loss: 0.0105
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0110 - val_loss: 0.0115
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0111 - val_loss: 0.0109
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0110 - val_loss: 0.0112
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0110 - val_loss: 0.0106
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0109 - val_loss: 0.0115
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0111 - val_loss: 0.0106
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0111 - val_loss: 0.0109
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0109 - val_loss: 0.0111
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0104 - val_loss: 0.0109
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0104 - val_loss: 0.0111
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0108 - val_loss: 0.0094
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0099 - val_loss: 0.0108
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0104 - val_loss: 0.0097
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0103 - val_loss: 0.0098
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0100 - val_loss: 0.0105
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0103 - val_loss: 0.0095
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0100 - val_loss: 0.0095
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0097 - val_loss: 0.0099
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0100 - val_loss: 0.0097
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0099 - val_loss: 0.0097
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 155ms/step
# [Simple LSTM] RMSLE (Store 23 - EGGS): 0.3671

# %% [markdown]
# ### Kombinasi 1 - Model LSTM Kompleks (2 Layer + Dropout)

# %%
model_complex_comb1 = build_complex_lstm(look_back=14)
rmsle_complex_comb1 = train_and_evaluate(
    model_complex_comb1, data_comb1, 
    model_name="Complex LSTM", store_nbr=23, family="EGGS", 
    epochs=50, batch_size=32
)
# Out:
# === Training Complex LSTM (Store 23 - EGGS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 45ms/step - loss: 0.0347 - val_loss: 0.0101
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0144 - val_loss: 0.0101
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0144 - val_loss: 0.0102
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0142 - val_loss: 0.0105
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0133 - val_loss: 0.0103
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0141 - val_loss: 0.0102
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0138 - val_loss: 0.0102
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0141 - val_loss: 0.0102
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0129 - val_loss: 0.0102
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0136 - val_loss: 0.0101
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0135 - val_loss: 0.0108
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0132 - val_loss: 0.0100
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0137 - val_loss: 0.0103
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0138 - val_loss: 0.0101
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0130 - val_loss: 0.0103
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 0.0130 - val_loss: 0.0102
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 0.0128 - val_loss: 0.0100
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0130 - val_loss: 0.0101
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0134 - val_loss: 0.0101
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0130 - val_loss: 0.0099
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0132 - val_loss: 0.0099
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0131 - val_loss: 0.0101
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0132 - val_loss: 0.0102
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0130 - val_loss: 0.0101
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0131 - val_loss: 0.0102
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0125 - val_loss: 0.0105
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0123 - val_loss: 0.0109
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0129 - val_loss: 0.0100
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0127 - val_loss: 0.0104
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0127 - val_loss: 0.0105
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0126 - val_loss: 0.0100
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0126 - val_loss: 0.0105
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0124 - val_loss: 0.0101
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0125 - val_loss: 0.0104
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0123 - val_loss: 0.0106
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0123 - val_loss: 0.0106
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0120 - val_loss: 0.0105
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0123 - val_loss: 0.0102
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0121 - val_loss: 0.0105
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0122 - val_loss: 0.0102
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0121 - val_loss: 0.0105
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0120 - val_loss: 0.0105
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0122 - val_loss: 0.0105
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0124 - val_loss: 0.0106
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0121 - val_loss: 0.0102
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0120 - val_loss: 0.0103
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0117 - val_loss: 0.0104
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0118 - val_loss: 0.0105
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step
# [Complex LSTM] RMSLE (Store 23 - EGGS): 0.3788

# %% [markdown]
# ---
# ## Kombinasi 2: Store 54 - MEATS

# %%
# Prepare Data Kombinasi 2 (Store 54, MEATS)
data_comb2 = prepare_data_lstm(df_train, store_nbr=54, family='MEATS', look_back=14)
print(f"Data Kombinasi 2 (Store 54 - MEATS) Siap!")
print(f"Shape X_train: {data_comb2['X_train'].shape}, Shape X_test: {data_comb2['X_test'].shape}")
# Out:
# Data Kombinasi 2 (Store 54 - MEATS) Siap!
# Shape X_train: (1339, 14, 1), Shape X_test: (335, 14, 1)

# %% [markdown]
# ### Kombinasi 2 - Model LSTM Sederhana

# %%
model_simple_comb2 = build_simple_lstm(look_back=14)
rmsle_simple_comb2 = train_and_evaluate(
    model_simple_comb2, data_comb2, 
    model_name="Simple LSTM", store_nbr=54, family="MEATS", 
    epochs=50, batch_size=32
)
# Out:
# === Training Simple LSTM (Store 54 - MEATS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - loss: 0.0504 - val_loss: 0.0135
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0225 - val_loss: 0.0137
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0192 - val_loss: 0.0134
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0191 - val_loss: 0.0140
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0191 - val_loss: 0.0141
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0191 - val_loss: 0.0146
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0192 - val_loss: 0.0143
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0190 - val_loss: 0.0142
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0188 - val_loss: 0.0142
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0186 - val_loss: 0.0144
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0187 - val_loss: 0.0145
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0185 - val_loss: 0.0146
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0185 - val_loss: 0.0143
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186 - val_loss: 0.0147
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0183 - val_loss: 0.0148
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0182 - val_loss: 0.0151
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0182 - val_loss: 0.0159
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0180 - val_loss: 0.0163
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0181 - val_loss: 0.0173
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0177 - val_loss: 0.0161
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0179 - val_loss: 0.0166
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0181 - val_loss: 0.0165
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0179 - val_loss: 0.0170
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0177 - val_loss: 0.0176
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0176 - val_loss: 0.0178
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0174 - val_loss: 0.0177
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0176 - val_loss: 0.0175
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0176 - val_loss: 0.0159
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0171 - val_loss: 0.0168
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0169 - val_loss: 0.0163
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0160 - val_loss: 0.0163
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0164 - val_loss: 0.0161
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0164 - val_loss: 0.0155
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0155 - val_loss: 0.0156
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0154 - val_loss: 0.0166
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0152 - val_loss: 0.0166
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0153 - val_loss: 0.0170
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0145 - val_loss: 0.0156
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0151 - val_loss: 0.0157
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0149 - val_loss: 0.0154
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0148 - val_loss: 0.0153
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0145 - val_loss: 0.0162
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0148 - val_loss: 0.0160
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0148 - val_loss: 0.0148
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0144 - val_loss: 0.0166
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0147 - val_loss: 0.0158
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0151 - val_loss: 0.0154
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0141 - val_loss: 0.0177
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step
# [Simple LSTM] RMSLE (Store 54 - MEATS): 0.4104

# %% [markdown]
# ### Kombinasi 2 - Model LSTM Kompleks (2 Layer + Dropout)

# %%
model_complex_comb2 = build_complex_lstm(look_back=14)
rmsle_complex_comb2 = train_and_evaluate(
    model_complex_comb2, data_comb2, 
    model_name="Complex LSTM", store_nbr=54, family="MEATS", 
    epochs=50, batch_size=32
)
# Out:
# === Training Complex LSTM (Store 54 - MEATS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step - loss: 0.0440 - val_loss: 0.0119
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0202 - val_loss: 0.0124
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0205 - val_loss: 0.0123
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0202 - val_loss: 0.0120
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0203 - val_loss: 0.0119
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0200 - val_loss: 0.0123
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0193 - val_loss: 0.0120
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0194 - val_loss: 0.0122
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0191 - val_loss: 0.0121
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0188 - val_loss: 0.0120
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0195 - val_loss: 0.0120
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0190 - val_loss: 0.0120
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0194 - val_loss: 0.0121
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0192 - val_loss: 0.0120
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0192 - val_loss: 0.0121
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0195 - val_loss: 0.0120
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0191 - val_loss: 0.0123
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0188 - val_loss: 0.0120
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0188 - val_loss: 0.0121
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0189 - val_loss: 0.0121
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0188 - val_loss: 0.0126
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0192 - val_loss: 0.0127
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0188 - val_loss: 0.0125
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0185 - val_loss: 0.0125
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0188 - val_loss: 0.0124
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0187 - val_loss: 0.0127
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0183 - val_loss: 0.0123
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0180 - val_loss: 0.0124
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0184 - val_loss: 0.0124
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0187 - val_loss: 0.0126
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0181 - val_loss: 0.0124
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0182 - val_loss: 0.0126
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0181 - val_loss: 0.0129
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0183 - val_loss: 0.0124
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0177 - val_loss: 0.0123
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0179 - val_loss: 0.0129
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0179 - val_loss: 0.0125
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0182 - val_loss: 0.0125
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0175 - val_loss: 0.0126
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0177 - val_loss: 0.0128
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0180 - val_loss: 0.0124
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0179 - val_loss: 0.0126
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0179 - val_loss: 0.0131
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0178 - val_loss: 0.0125
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0175 - val_loss: 0.0124
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0179 - val_loss: 0.0127
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0174 - val_loss: 0.0125
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0176 - val_loss: 0.0124
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 19s 419ms/step - loss: 0.0176 - val_loss: 0.0125
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 26ms/step - loss: 0.0177 - val_loss: 0.0127
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 464ms/step
# [Complex LSTM] RMSLE (Store 54 - MEATS): 0.3866

# %% [markdown]
# ---
# ## Kombinasi 3: Store 19 - PREPARED FOODS

# %%
# Prepare Data Kombinasi 3 (Store 19, PREPARED FOODS)
data_comb3 = prepare_data_lstm(df_train, store_nbr=19, family='PREPARED FOODS', look_back=14)
print(f"Data Kombinasi 3 (Store 19 - PREPARED FOODS) Siap!")
print(f"Shape X_train: {data_comb3['X_train'].shape}, Shape X_test: {data_comb3['X_test'].shape}")
# Out:
# Data Kombinasi 3 (Store 19 - PREPARED FOODS) Siap!
# Shape X_train: (1339, 14, 1), Shape X_test: (335, 14, 1)

# %% [markdown]
# ### Kombinasi 3 - Model LSTM Sederhana

# %%
model_simple_comb3 = build_simple_lstm(look_back=14)
rmsle_simple_comb3 = train_and_evaluate(
    model_simple_comb3, data_comb3, 
    model_name="Simple LSTM", store_nbr=19, family="PREPARED FOODS", 
    epochs=50, batch_size=32
)
# Out:
# === Training Simple LSTM (Store 19 - PREPARED FOODS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - loss: 0.0576 - val_loss: 0.0309
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0253 - val_loss: 0.0300
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0232 - val_loss: 0.0326
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0229 - val_loss: 0.0330
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0230 - val_loss: 0.0325
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0228 - val_loss: 0.0318
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0223 - val_loss: 0.0313
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0224 - val_loss: 0.0304
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0217 - val_loss: 0.0303
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0220 - val_loss: 0.0293
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0216 - val_loss: 0.0275
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0213 - val_loss: 0.0320
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0211 - val_loss: 0.0279
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0207 - val_loss: 0.0278
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0203 - val_loss: 0.0305
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0212 - val_loss: 0.0294
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0209 - val_loss: 0.0294
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0212 - val_loss: 0.0275
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0203 - val_loss: 0.0306
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0208 - val_loss: 0.0312
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0206 - val_loss: 0.0283
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0203 - val_loss: 0.0298
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0201 - val_loss: 0.0280
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0209 - val_loss: 0.0300
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 190ms/step - loss: 0.0201 - val_loss: 0.0322
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - loss: 0.0200 - val_loss: 0.0293
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0205 - val_loss: 0.0279
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0206 - val_loss: 0.0301
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0207 - val_loss: 0.0286
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0202 - val_loss: 0.0299
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0204 - val_loss: 0.0274
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0205 - val_loss: 0.0278
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0208 - val_loss: 0.0321
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0210 - val_loss: 0.0287
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0206 - val_loss: 0.0277
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0207 - val_loss: 0.0303
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0202 - val_loss: 0.0318
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0203 - val_loss: 0.0305
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0205 - val_loss: 0.0316
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0206 - val_loss: 0.0282
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0200 - val_loss: 0.0304
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0204 - val_loss: 0.0293
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0202 - val_loss: 0.0291
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0207 - val_loss: 0.0279
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0204 - val_loss: 0.0296
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0204 - val_loss: 0.0274
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0199 - val_loss: 0.0319
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0201 - val_loss: 0.0282
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0203 - val_loss: 0.0303
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0199 - val_loss: 0.0278
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
# [Simple LSTM] RMSLE (Store 19 - PREPARED FOODS): 0.4195

# %% [markdown]
# ### Kombinasi 3 - Model LSTM Kompleks (2 Layer + Dropout)

# %%
model_complex_comb3 = build_complex_lstm(look_back=14)
rmsle_complex_comb3 = train_and_evaluate(
    model_complex_comb3, data_comb3, 
    model_name="Complex LSTM", store_nbr=19, family="PREPARED FOODS", 
    epochs=50, batch_size=32
)
# Out:
# === Training Complex LSTM (Store 19 - PREPARED FOODS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 0.0323 - val_loss: 0.0243
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.0217 - val_loss: 0.0244
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0219 - val_loss: 0.0239
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0211 - val_loss: 0.0239
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0212 - val_loss: 0.0239
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0218 - val_loss: 0.0240
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0219 - val_loss: 0.0240
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0215 - val_loss: 0.0239
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0215 - val_loss: 0.0239
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0212 - val_loss: 0.0239
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0210 - val_loss: 0.0239
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0215 - val_loss: 0.0239
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0216 - val_loss: 0.0240
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0210 - val_loss: 0.0238
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0218 - val_loss: 0.0239
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0204 - val_loss: 0.0238
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0210 - val_loss: 0.0238
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - loss: 0.0205 - val_loss: 0.0238
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0208 - val_loss: 0.0238
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0209 - val_loss: 0.0238
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0209 - val_loss: 0.0238
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0208 - val_loss: 0.0239
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0209 - val_loss: 0.0238
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0209 - val_loss: 0.0238
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0208 - val_loss: 0.0238
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0206 - val_loss: 0.0238
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0205 - val_loss: 0.0237
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0203 - val_loss: 0.0237
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0201 - val_loss: 0.0237
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0208 - val_loss: 0.0237
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0209 - val_loss: 0.0237
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0205 - val_loss: 0.0238
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - loss: 0.0200 - val_loss: 0.0237
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0208 - val_loss: 0.0237
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0206 - val_loss: 0.0236
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0201 - val_loss: 0.0236
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0204 - val_loss: 0.0236
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0205 - val_loss: 0.0236
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0204 - val_loss: 0.0236
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0202 - val_loss: 0.0237
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0204 - val_loss: 0.0236
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0204 - val_loss: 0.0236
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0200 - val_loss: 0.0235
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0202 - val_loss: 0.0236
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0202 - val_loss: 0.0235
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0202 - val_loss: 0.0235
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0200 - val_loss: 0.0235
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0199 - val_loss: 0.0235
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - loss: 0.0202 - val_loss: 0.0235
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0201 - val_loss: 0.0235
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# [Complex LSTM] RMSLE (Store 19 - PREPARED FOODS): 0.4198

# %% [markdown]
# ---
# ## Kombinasi 4: Store 7 - SEAFOOD

# %%
# Prepare Data Kombinasi 4 (Store 7, SEAFOOD)
data_comb4 = prepare_data_lstm(df_train, store_nbr=7, family='SEAFOOD', look_back=14)
print(f"Data Kombinasi 4 (Store 7 - SEAFOOD) Siap!")
print(f"Shape X_train: {data_comb4['X_train'].shape}, Shape X_test: {data_comb4['X_test'].shape}")
# Out:
# Data Kombinasi 4 (Store 7 - SEAFOOD) Siap!
# Shape X_train: (1339, 14, 1), Shape X_test: (335, 14, 1)

# %% [markdown]
# ### Kombinasi 4 - Model LSTM Sederhana

# %%
model_simple_comb4 = build_simple_lstm(look_back=14)
rmsle_simple_comb4 = train_and_evaluate(
    model_simple_comb4, data_comb4, 
    model_name="Simple LSTM", store_nbr=7, family="SEAFOOD", 
    epochs=50, batch_size=32
)
# Out:
# === Training Simple LSTM (Store 7 - SEAFOOD) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 0.0626 - val_loss: 0.0154
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0260 - val_loss: 0.0195
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0203 - val_loss: 0.0206
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0204 - val_loss: 0.0215
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0201 - val_loss: 0.0201
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0200 - val_loss: 0.0200
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0198 - val_loss: 0.0193
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0195 - val_loss: 0.0181
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0193 - val_loss: 0.0172
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0193 - val_loss: 0.0169
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0187 - val_loss: 0.0157
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0187 - val_loss: 0.0154
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0187 - val_loss: 0.0147
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0183 - val_loss: 0.0146
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0184 - val_loss: 0.0146
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0186 - val_loss: 0.0147
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0187 - val_loss: 0.0146
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0185 - val_loss: 0.0146
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0184 - val_loss: 0.0147
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0183 - val_loss: 0.0145
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 0.0186 - val_loss: 0.0146
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0182 - val_loss: 0.0146
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0182 - val_loss: 0.0145
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0185 - val_loss: 0.0145
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0185 - val_loss: 0.0145
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0180 - val_loss: 0.0145
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0187 - val_loss: 0.0145
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0184 - val_loss: 0.0145
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0185 - val_loss: 0.0146
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.0184 - val_loss: 0.0145
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0184 - val_loss: 0.0145
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0187 - val_loss: 0.0146
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0182 - val_loss: 0.0145
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0182 - val_loss: 0.0146
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0182 - val_loss: 0.0144
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0183 - val_loss: 0.0148
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0180 - val_loss: 0.0146
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0184 - val_loss: 0.0144
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0182 - val_loss: 0.0144
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0180 - val_loss: 0.0146
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0186 - val_loss: 0.0144
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0180 - val_loss: 0.0145
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0179 - val_loss: 0.0143
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0184 - val_loss: 0.0145
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0184 - val_loss: 0.0144
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0181 - val_loss: 0.0143
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0177 - val_loss: 0.0145
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0178 - val_loss: 0.0143
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - loss: 0.0182 - val_loss: 0.0143
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0179 - val_loss: 0.0144
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
# [Simple LSTM] RMSLE (Store 7 - SEAFOOD): 0.4172

# %% [markdown]
# ### Kombinasi 4 - Model LSTM Kompleks (2 Layer + Dropout)

# %%
model_complex_comb4 = build_complex_lstm(look_back=14)
rmsle_complex_comb4 = train_and_evaluate(
    model_complex_comb4, data_comb4, 
    model_name="Complex LSTM", store_nbr=7, family="SEAFOOD", 
    epochs=50, batch_size=32
)
# Out:
# === Training Complex LSTM (Store 7 - SEAFOOD) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 17s 80ms/step - loss: 0.0568 - val_loss: 0.0190
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0211 - val_loss: 0.0165
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0203 - val_loss: 0.0164
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0205 - val_loss: 0.0156
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0203 - val_loss: 0.0160
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0202 - val_loss: 0.0159
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0199 - val_loss: 0.0151
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0199 - val_loss: 0.0160
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0198 - val_loss: 0.0156
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 54ms/step - loss: 0.0203 - val_loss: 0.0155
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0197 - val_loss: 0.0155
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0198 - val_loss: 0.0156
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0197 - val_loss: 0.0161
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0202 - val_loss: 0.0160
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0196 - val_loss: 0.0155
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0195 - val_loss: 0.0155
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0194 - val_loss: 0.0158
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0188 - val_loss: 0.0157
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0199 - val_loss: 0.0158
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0193 - val_loss: 0.0156
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0195 - val_loss: 0.0163
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0194 - val_loss: 0.0160
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0189 - val_loss: 0.0154
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0190 - val_loss: 0.0160
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0196 - val_loss: 0.0155
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0190 - val_loss: 0.0155
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0188 - val_loss: 0.0156
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 78ms/step - loss: 0.0196 - val_loss: 0.0155
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0192 - val_loss: 0.0163
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0182 - val_loss: 0.0161
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0193 - val_loss: 0.0159
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0189 - val_loss: 0.0152
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0188 - val_loss: 0.0157
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0187 - val_loss: 0.0155
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.0190 - val_loss: 0.0159
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0183 - val_loss: 0.0158
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0189 - val_loss: 0.0158
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0188 - val_loss: 0.0152
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0186 - val_loss: 0.0159
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0189 - val_loss: 0.0156
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0188 - val_loss: 0.0162
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0187 - val_loss: 0.0153
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0184 - val_loss: 0.0153
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0189 - val_loss: 0.0156
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0185 - val_loss: 0.0150
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0190 - val_loss: 0.0155
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0186 - val_loss: 0.0154
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0185 - val_loss: 0.0150
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 0.0181 - val_loss: 0.0155
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0188 - val_loss: 0.0159
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step
# [Complex LSTM] RMSLE (Store 7 - SEAFOOD): 0.4358

# %% [markdown]
# ---
# ## Kombinasi 5: Store 23 - PREPARED FOODS

# %%
# Prepare Data Kombinasi 5 (Store 23, PREPARED FOODS)
data_comb5 = prepare_data_lstm(df_train, store_nbr=7, family='PREPARED FOODS', look_back=14)
print(f"Data Kombinasi 5 (Store 23 - PREPARED FOODS	) Siap!")
print(f"Shape X_train: {data_comb5['X_train'].shape}, Shape X_test: {data_comb5['X_test'].shape}")
# Out:
# Data Kombinasi 5 (Store 23 - PREPARED FOODS	) Siap!
# Shape X_train: (1339, 14, 1), Shape X_test: (335, 14, 1)

# %% [markdown]
# ### Kombinasi 5 - Model LSTM Sederhana

# %%
model_simple_comb5 = build_simple_lstm(look_back=14)
rmsle_simple_comb5 = train_and_evaluate(
    model_simple_comb5, data_comb5, 
    model_name="Simple LSTM", store_nbr=23, family="PREPARED FOODS", 
    epochs=50, batch_size=32
)
# Out:
# === Training Simple LSTM (Store 23 - PREPARED FOODS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0807 - val_loss: 0.0140
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0248 - val_loss: 0.0179
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0148 - val_loss: 0.0187
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0145 - val_loss: 0.0183
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0144 - val_loss: 0.0179
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0143 - val_loss: 0.0173
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0142 - val_loss: 0.0170
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0140 - val_loss: 0.0163
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0138 - val_loss: 0.0161
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0137 - val_loss: 0.0156
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0133 - val_loss: 0.0151
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0133 - val_loss: 0.0147
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0133 - val_loss: 0.0150
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0131 - val_loss: 0.0152
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0133 - val_loss: 0.0154
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0133 - val_loss: 0.0154
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0131 - val_loss: 0.0156
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0129 - val_loss: 0.0160
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0130 - val_loss: 0.0152
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0126 - val_loss: 0.0155
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0128 - val_loss: 0.0169
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0132 - val_loss: 0.0166
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0132 - val_loss: 0.0160
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0128 - val_loss: 0.0162
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0128 - val_loss: 0.0166
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0131 - val_loss: 0.0169
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0133 - val_loss: 0.0156
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0129 - val_loss: 0.0159
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0128 - val_loss: 0.0153
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0128 - val_loss: 0.0156
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0128 - val_loss: 0.0161
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0132 - val_loss: 0.0154
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0131 - val_loss: 0.0160
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0130 - val_loss: 0.0157
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0128 - val_loss: 0.0153
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0129 - val_loss: 0.0152
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0130 - val_loss: 0.0153
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0129 - val_loss: 0.0152
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0130 - val_loss: 0.0151
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - loss: 0.0129 - val_loss: 0.0153
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0128 - val_loss: 0.0156
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0130 - val_loss: 0.0150
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0130 - val_loss: 0.0152
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0130 - val_loss: 0.0145
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0127 - val_loss: 0.0155
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0131 - val_loss: 0.0153
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0125 - val_loss: 0.0156
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0128 - val_loss: 0.0162
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0132 - val_loss: 0.0162
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0128 - val_loss: 0.0156
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step
# [Simple LSTM] RMSLE (Store 23 - PREPARED FOODS): 0.4414

# %% [markdown]
# ### Kombinasi 5 - Model LSTM Kompleks (2 Layer + Dropout)

# %%
model_complex_comb5 = build_complex_lstm(look_back=14)
rmsle_complex_comb5 = train_and_evaluate(
    model_complex_comb5, data_comb5, 
    model_name="Complex LSTM", store_nbr=23, family="PREPARED FOODS", 
    epochs=50, batch_size=32
)
# Out:
# === Training Complex LSTM (Store 23 - PREPARED FOODS) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 64ms/step - loss: 0.0492 - val_loss: 0.0138
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0165 - val_loss: 0.0140
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0161 - val_loss: 0.0140
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0148 - val_loss: 0.0137
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0153 - val_loss: 0.0135
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.0159 - val_loss: 0.0133
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 0.0155 - val_loss: 0.0130
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0150 - val_loss: 0.0129
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0158 - val_loss: 0.0131
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0154 - val_loss: 0.0129
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0151 - val_loss: 0.0131
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0151 - val_loss: 0.0128
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0150 - val_loss: 0.0132
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0152 - val_loss: 0.0137
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0150 - val_loss: 0.0132
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0149 - val_loss: 0.0130
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0152 - val_loss: 0.0132
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0144 - val_loss: 0.0132
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0154 - val_loss: 0.0141
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0142 - val_loss: 0.0133
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0150 - val_loss: 0.0130
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0146 - val_loss: 0.0135
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0145 - val_loss: 0.0136
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0145 - val_loss: 0.0133
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0149 - val_loss: 0.0133
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0146 - val_loss: 0.0135
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0139 - val_loss: 0.0132
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0144 - val_loss: 0.0134
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0139 - val_loss: 0.0133
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0137 - val_loss: 0.0132
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0137 - val_loss: 0.0131
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0140 - val_loss: 0.0133
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0140 - val_loss: 0.0132
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 0.0142 - val_loss: 0.0132
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0135 - val_loss: 0.0133
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0137 - val_loss: 0.0131
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0139 - val_loss: 0.0135
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.0138 - val_loss: 0.0144
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0135 - val_loss: 0.0135
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0136 - val_loss: 0.0135
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0136 - val_loss: 0.0135
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0137 - val_loss: 0.0133
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0140 - val_loss: 0.0134
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0138 - val_loss: 0.0134
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0132 - val_loss: 0.0133
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0135 - val_loss: 0.0129
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0137 - val_loss: 0.0139
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0137 - val_loss: 0.0131
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0135 - val_loss: 0.0135
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0132 - val_loss: 0.0134
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step
# [Complex LSTM] RMSLE (Store 23 - PREPARED FOODS): 0.4460

# %% [markdown]
# ---
# ## Kombinasi 6: Store 44 - GROCERY I

# %%
# Prepare Data Kombinasi 6 (Store 44, GROCERY I)
data_comb6 = prepare_data_lstm(df_train, store_nbr=44, family='GROCERY I', look_back=14)
print(f"Data Kombinasi 6 (Store 44 - GROCERY I) Siap!")
print(f"Shape X_train: {data_comb6['X_train'].shape}, Shape X_test: {data_comb6['X_test'].shape}")
# Out:
# Data Kombinasi 6 (Store 44 - GROCERY I) Siap!
# Shape X_train: (1339, 14, 1), Shape X_test: (335, 14, 1)

# %% [markdown]
# ### Kombinasi 6 - Model LSTM Sederhana

# %%
model_simple_comb6 = build_simple_lstm(look_back=14)
rmsle_simple_comb6 = train_and_evaluate(
    model_simple_comb6, data_comb6, 
    model_name="Simple LSTM", store_nbr=44, family="GROCERY I", 
    epochs=50, batch_size=32
)
# Out:
# === Training Simple LSTM (Store 44 - GROCERY I) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 0.0098 - val_loss: 0.0063
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0058 - val_loss: 0.0069
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0058 - val_loss: 0.0071
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0057 - val_loss: 0.0069
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0058 - val_loss: 0.0072
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0057 - val_loss: 0.0073
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0056 - val_loss: 0.0072
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0057 - val_loss: 0.0072
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0057 - val_loss: 0.0071
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0056 - val_loss: 0.0072
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0056 - val_loss: 0.0074
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0055 - val_loss: 0.0071
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0055 - val_loss: 0.0071
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0055 - val_loss: 0.0070
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0054 - val_loss: 0.0071
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0053 - val_loss: 0.0064
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0053 - val_loss: 0.0069
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0052 - val_loss: 0.0069
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0052 - val_loss: 0.0073
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0051 - val_loss: 0.0062
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0051 - val_loss: 0.0071
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0048 - val_loss: 0.0061
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0048 - val_loss: 0.0061
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 7s 127ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0045 - val_loss: 0.0052
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0046 - val_loss: 0.0056
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.0045 - val_loss: 0.0055
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0044 - val_loss: 0.0053
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0043 - val_loss: 0.0049
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044 - val_loss: 0.0051
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 0.0043 - val_loss: 0.0055
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0043 - val_loss: 0.0046
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0043 - val_loss: 0.0054
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0042 - val_loss: 0.0048
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0042 - val_loss: 0.0059
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0044 - val_loss: 0.0049
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# [Simple LSTM] RMSLE (Store 44 - GROCERY I): 0.7676

# %% [markdown]
# ### Kombinasi 6 - Model LSTM Kompleks (2 Layer + Dropout)

# %%
model_complex_comb6 = build_complex_lstm(look_back=14)
rmsle_complex_comb6 = train_and_evaluate(
    model_complex_comb6, data_comb6, 
    model_name="Complex LSTM", store_nbr=44, family="GROCERY I", 
    epochs=50, batch_size=32
)
# Out:
# === Training Complex LSTM (Store 44 - GROCERY I) ===
# Epoch 1/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 13s 40ms/step - loss: 0.0089 - val_loss: 0.0063
# Epoch 2/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 3/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 4/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 5/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 6/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 7/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0059 - val_loss: 0.0060
# Epoch 8/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 9/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0057 - val_loss: 0.0060
# Epoch 10/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.0058 - val_loss: 0.0059
# Epoch 11/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0058 - val_loss: 0.0060
# Epoch 12/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0058 - val_loss: 0.0061
# Epoch 13/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0059 - val_loss: 0.0062
# Epoch 14/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 15/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 16/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 17/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 18/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 19/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0059 - val_loss: 0.0063
# Epoch 20/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0058 - val_loss: 0.0063
# Epoch 21/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 22/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 23/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0057 - val_loss: 0.0062
# Epoch 24/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 25/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0058 - val_loss: 0.0062
# Epoch 26/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0056 - val_loss: 0.0064
# Epoch 27/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 28/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 29/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 30/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0056 - val_loss: 0.0061
# Epoch 31/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0056 - val_loss: 0.0062
# Epoch 32/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 33/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0055 - val_loss: 0.0058
# Epoch 34/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 35/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 36/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - loss: 0.0055 - val_loss: 0.0060
# Epoch 37/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0056 - val_loss: 0.0063
# Epoch 38/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 39/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 40/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0055 - val_loss: 0.0062
# Epoch 41/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0055 - val_loss: 0.0063
# Epoch 42/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0055 - val_loss: 0.0064
# Epoch 43/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 44/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 45/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 46/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 47/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 101ms/step - loss: 0.0054 - val_loss: 0.0060
# Epoch 48/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 43ms/step - loss: 0.0054 - val_loss: 0.0062
# Epoch 49/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 50/50
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0053 - val_loss: 0.0057
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 148ms/step
# [Complex LSTM] RMSLE (Store 44 - GROCERY I): 0.7775

# %% [markdown]
# ---
# ## Ringkasan Perbandingan Performa Eksperimen

# %%
summary_data = [
    {'Store': 23, 'Family': 'EGGS', 'Model': 'Simple LSTM', 'RMSLE': rmsle_simple_comb1},
    {'Store': 23, 'Family': 'EGGS', 'Model': 'Complex LSTM', 'RMSLE': rmsle_complex_comb1},
    {'Store': 54, 'Family': 'MEATS', 'Model': 'Simple LSTM', 'RMSLE': rmsle_simple_comb2},
    {'Store': 54, 'Family': 'MEATS', 'Model': 'Complex LSTM', 'RMSLE': rmsle_complex_comb2},
    {'Store': 19, 'Family': 'PREPARED FOODS', 'Model': 'Simple LSTM', 'RMSLE': rmsle_simple_comb3},
    {'Store': 19, 'Family': 'PREPARED FOODS', 'Model': 'Complex LSTM', 'RMSLE': rmsle_complex_comb3},
    {'Store': 7, 'Family': 'SEAFOOD', 'Model': 'Simple LSTM', 'RMSLE': rmsle_simple_comb4},
    {'Store': 7, 'Family': 'SEAFOOD', 'Model': 'Complex LSTM', 'RMSLE': rmsle_complex_comb4},
    {'Store': 23, 'Family': 'PREPARED FOODS', 'Model': 'Simple LSTM', 'RMSLE': rmsle_simple_comb5},
    {'Store': 23, 'Family': 'PREPARED FOODS', 'Model': 'Complex LSTM', 'RMSLE': rmsle_complex_comb5},
    {'Store': 44, 'Family': 'GROCERY I', 'Model': 'Simple LSTM', 'RMSLE': rmsle_simple_comb6},
    {'Store': 44, 'Family': 'GROCERY I', 'Model': 'Complex LSTM', 'RMSLE': rmsle_complex_comb6},
]

df_summary = pd.DataFrame(summary_data)
display(df_summary)
# Out:
#     Store          Family         Model     RMSLE
# 0      23            EGGS   Simple LSTM  0.367118
# 1      23            EGGS  Complex LSTM  0.378845
# 2      54           MEATS   Simple LSTM  0.410414
# 3      54           MEATS  Complex LSTM  0.386627
# 4      19  PREPARED FOODS   Simple LSTM  0.419507
# 5      19  PREPARED FOODS  Complex LSTM  0.419816
# 6       7         SEAFOOD   Simple LSTM  0.417172
# 7       7         SEAFOOD  Complex LSTM  0.435805
# 8      23  PREPARED FOODS   Simple LSTM  0.441389
# 9      23  PREPARED FOODS  Complex LSTM  0.446001
# 10     44       GROCERY I   Simple LSTM  0.767616
# 11     44       GROCERY I  Complex LSTM  0.777492
